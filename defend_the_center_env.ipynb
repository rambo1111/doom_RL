# %% [markdown]
# # Getting VizDoom Up and Running

# %%
# Import vizdoom for game env
from vizdoom import * 
# Import random for action sampling
import random
# Import time for sleeping
import time 
# Import numpy for identity matrix
import numpy as np

# %%
# Setup game
game = DoomGame()
game.load_config('configs/defend_the_center.cfg')
game.init()

# %%
# This is the set of actions we can take in the environment
actions = np.identity(3, dtype=np.uint8)
random.choice(actions)
# Out:
# array([0, 0, 1], dtype=uint8)

# %%
# Loop through episodes 
episodes = 10
for episode in range(episodes): 
    # Create a new episode or game 
    game.new_episode()
    # Check the game isn't done 
    while not game.is_episode_finished(): 
        # Get the game state 
        state = game.get_state()
        # Get the game image 
        img = state.screen_buffer
        # Get the game variables - anmo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions),4) # When our agent will take action it will skip 4 frames after taking the action.
        # Print rewward 
        print('reward:', reward) 
        time.sleep(0.02)
    print('Result:', game.get_total_reward())
    time.sleep(2)
# Out:
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: -1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: -1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: -1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 3.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 0.0

# %%
game.close()

# %% [markdown]
# # 2. Converting it to a Gym Environment

# %%
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces 
from gym.spaces import Discrete, Box
# Import opencv 
import cv2

# %%
actions[Discrete(3).sample()]
# Out:
# array([0, 0, 1], dtype=uint8)

# %%
Box(low=0, high=10, shape=(320,240), dtype=np.uint8).sample()
# Out:
# array([[ 4,  2,  2, ...,  6, 10,  5],
#        [ 3,  2,  1, ...,  1, 10,  6],
#        [ 3,  7,  5, ..., 10,  1,  0],
#        ...,
#        [10,  3,  5, ..., 10,  1,  8],
#        [ 4,  4,  8, ...,  5,  6,  1],
#        [ 9, 10,  6, ...,  1,  1,  6]], dtype=uint8)

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env): 
    # Function that is called when we start the env
    def __init__(self, render=False): 
        # Inherit from Env
        super().__init__()
        # Setup the game 
        self.game = DoomGame()
        self.game.load_config('configs/defend_the_center.cfg')
        
        # Render frame logic
        if render == False: 
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(3)
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) 
        
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            anmo = self.game.get_state().game_variables[0]
            info = anmo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Define how to render the game or environment 
    def render(): 
        pass
    
    # What happens when we start a new game 
    def reset(self): 
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env = VizDoomGym(render=True)

# %%
state = env.reset()

# %%
env.close()

# %% [markdown]
# # 3. View Game State

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Environment Cheker

# %%
# Import Environment checker
from stable_baselines3.common import env_checker
env_checker.check_env(env)

# %% [markdown]
# # 4. Setup Callback

# %%
# Import os for file nav
import os 
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './models/models_defend_the_center'
LOG_DIR = './logs/log_defend_the_center'

# %%
callback = TrainAndLoggingCallback(check_freq=100000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # 5. Train Model

# %%
# import ppo for training
from stable_baselines3 import PPO

# %%
# Non rendered environment
env = VizDoomGym()

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=4096)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/log_defend_the_center\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.6     |
# |    ep_rew_mean     | 0.429    |
# | time/              |          |
# |    fps             | 38       |
# |    iterations      | 1        |
# |    time_elapsed    | 106      |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84          |
# |    ep_rew_mean          | 0.474       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 2           |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010763184 |
# |    clip_fraction        | 0.0706      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00246    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0319      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00651    |
# |    value_loss           | 0.111       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.8        |
# |    ep_rew_mean          | 0.83        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 3           |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012630328 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0147     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 0.103       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.7        |
# |    ep_rew_mean          | 1.55        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 4           |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013109895 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.496       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0329     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0312     |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | 2.19        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 5           |
# |    time_elapsed         | 604         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015223783 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0107     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | 2.94        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 6           |
# |    time_elapsed         | 728         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.018259386 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0439     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0464     |
# |    value_loss           | 0.145       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | 3.65        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 7           |
# |    time_elapsed         | 843         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.021736674 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0382     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0481     |
# |    value_loss           | 0.173       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | 4.36        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 8           |
# |    time_elapsed         | 954         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020357404 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0068      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 0.198       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 5.03        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 9           |
# |    time_elapsed         | 1070        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020950709 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0177     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0464     |
# |    value_loss           | 0.166       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 130        |
# |    ep_rew_mean          | 5.36       |
# | time/                   |            |
# |    fps                  | 34         |
# |    iterations           | 10         |
# |    time_elapsed         | 1180       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02443495 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.85      |
# |    explained_variance   | 0.748      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0178    |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0458    |
# |    value_loss           | 0.168      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 136        |
# |    ep_rew_mean          | 5.84       |
# | time/                   |            |
# |    fps                  | 34         |
# |    iterations           | 11         |
# |    time_elapsed         | 1291       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02533076 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.811     |
# |    explained_variance   | 0.765      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.038     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0478    |
# |    value_loss           | 0.174      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 6.44        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 12          |
# |    time_elapsed         | 1403        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.024385322 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00737    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0472     |
# |    value_loss           | 0.148       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 6.66        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 13          |
# |    time_elapsed         | 1518        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.026424238 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.746      |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0436     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 0.15        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 153        |
# |    ep_rew_mean          | 7.29       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 14         |
# |    time_elapsed         | 1630       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.02782964 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.696     |
# |    explained_variance   | 0.84       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0467    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0459    |
# |    value_loss           | 0.17       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 159        |
# |    ep_rew_mean          | 7.73       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 15         |
# |    time_elapsed         | 1738       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.03223277 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.704     |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.038     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0473    |
# |    value_loss           | 0.133      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 163        |
# |    ep_rew_mean          | 8.07       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 16         |
# |    time_elapsed         | 1847       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02630721 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.701     |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00546   |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0445    |
# |    value_loss           | 0.133      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 169         |
# |    ep_rew_mean          | 8.61        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 17          |
# |    time_elapsed         | 1963        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.034519095 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0513     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0477     |
# |    value_loss           | 0.157       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 172        |
# |    ep_rew_mean          | 8.97       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 18         |
# |    time_elapsed         | 2077       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.03202918 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.671     |
# |    explained_variance   | 0.904      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0418    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0426    |
# |    value_loss           | 0.144      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 168        |
# |    ep_rew_mean          | 8.89       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 19         |
# |    time_elapsed         | 2192       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02721561 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.672     |
# |    explained_variance   | 0.925      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0419    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0462    |
# |    value_loss           | 0.142      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 162        |
# |    ep_rew_mean          | 8.76       |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 20         |
# |    time_elapsed         | 2305       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03317008 |
# |    clip_fraction        | 0.27       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.684     |
# |    explained_variance   | 0.921      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0279    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0463    |
# |    value_loss           | 0.145      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 8.25        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 21          |
# |    time_elapsed         | 2445        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.031492077 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0324     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0484     |
# |    value_loss           | 0.143       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 8.18        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 22          |
# |    time_elapsed         | 2475        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.034742337 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.676      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0158     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 8.32        |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 23          |
# |    time_elapsed         | 2502        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.037882246 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0126     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0481     |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 8.48        |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 24          |
# |    time_elapsed         | 2595        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.035229363 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0566     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 0.119       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 162        |
# |    ep_rew_mean          | 8.89       |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 25         |
# |    time_elapsed         | 2694       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.03225245 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.631     |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0393    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0449    |
# |    value_loss           | 0.146      |
# ----------------------------------------

# %% [markdown]
# # 6. Test the Model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disc
model = PPO.load('./models/models_defend_the_center/best_model_100000')

# %%
# Create rendered environment
env = VizDoomGym(render=True)

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
mean_reward
# Out:
# c:\Users\vibha\miniconda3\envs\py38\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# 9.7

# %%
for episode in range(100): 
    obs = env.reset()
    done = False
    total_reward = 0
    while not done: 
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        # time.sleep(0.20)
        total_reward += reward
    print('Total Reward for episode {} is {}'.format(episode+1, total_reward))
    # time.sleep(1)
# Out:
# Total Reward for episode 1 is 13.0
# Total Reward for episode 2 is 10.0
# Total Reward for episode 3 is 13.0
# Total Reward for episode 4 is 10.0
# Total Reward for episode 5 is 11.0
# Total Reward for episode 6 is 8.0
# Total Reward for episode 7 is 10.0
# Total Reward for episode 8 is 8.0
# Total Reward for episode 9 is 12.0
# Total Reward for episode 10 is 10.0
# Total Reward for episode 11 is 9.0
# Total Reward for episode 12 is 8.0
# Total Reward for episode 13 is 12.0
# Total Reward for episode 14 is 9.0
# Total Reward for episode 15 is 7.0
# Total Reward for episode 16 is 8.0
# Total Reward for episode 17 is 9.0
# Total Reward for episode 18 is 11.0
# Total Reward for episode 19 is 8.0
# Total Reward for episode 20 is 10.0
# Total Reward for episode 21 is 10.0
# Total Reward for episode 22 is 9.0
# Total Reward for episode 23 is 9.0
# Total Reward for episode 24 is 7.0
# Total Reward for episode 25 is 11.0
# Total Reward for episode 26 is 11.0
# Total Reward for episode 27 is 10.0
# Total Reward for episode 28 is 10.0
# Total Reward for episode 29 is 9.0
# Total Reward for episode 30 is 12.0
# Total Reward for episode 31 is 8.0
# Total Reward for episode 32 is 9.0
# Total Reward for episode 33 is 12.0
# Total Reward for episode 34 is 13.0
# Total Reward for episode 35 is 10.0
# Total Reward for episode 36 is 10.0
# Total Reward for episode 37 is 7.0
# Total Reward for episode 38 is 9.0
# Total Reward for episode 39 is 8.0
# Total Reward for episode 40 is 8.0
# Total Reward for episode 41 is 9.0
# Total Reward for episode 42 is 11.0
# Total Reward for episode 43 is 8.0
# Total Reward for episode 44 is 8.0
# Total Reward for episode 45 is 8.0
# Total Reward for episode 46 is 7.0
# Total Reward for episode 47 is 8.0
# Total Reward for episode 48 is 10.0
# Total Reward for episode 49 is 12.0
# Total Reward for episode 50 is 10.0
# Total Reward for episode 51 is 8.0
# Total Reward for episode 52 is 9.0
# Total Reward for episode 53 is 12.0
# Total Reward for episode 54 is 13.0
# Total Reward for episode 55 is 9.0
# Total Reward for episode 56 is 12.0
# Total Reward for episode 57 is 10.0
# Total Reward for episode 58 is 10.0
# Total Reward for episode 59 is 11.0
# Total Reward for episode 60 is 10.0
# Total Reward for episode 61 is 10.0
# Total Reward for episode 62 is 10.0
# Total Reward for episode 63 is 10.0
# Total Reward for episode 64 is 10.0
# Total Reward for episode 65 is 12.0
# Total Reward for episode 66 is 9.0
# Total Reward for episode 67 is 7.0
# Total Reward for episode 68 is 8.0
# Total Reward for episode 69 is 6.0
# Total Reward for episode 70 is 11.0
# Total Reward for episode 71 is 10.0
# Total Reward for episode 72 is 10.0
# Total Reward for episode 73 is 9.0
# Total Reward for episode 74 is 8.0
# Total Reward for episode 75 is 11.0
# Total Reward for episode 76 is 12.0
# Total Reward for episode 77 is 9.0
# Total Reward for episode 78 is 8.0
# Total Reward for episode 79 is 10.0
# Total Reward for episode 80 is 9.0
# Total Reward for episode 81 is 8.0
# Total Reward for episode 82 is 13.0
# Total Reward for episode 83 is 8.0
# Total Reward for episode 84 is 9.0
# Total Reward for episode 85 is 8.0
# Total Reward for episode 86 is 10.0
# Total Reward for episode 87 is 7.0
# Total Reward for episode 88 is 12.0
# Total Reward for episode 89 is 9.0
# Total Reward for episode 90 is 7.0
# Total Reward for episode 91 is 13.0
# Total Reward for episode 92 is 7.0
# Total Reward for episode 93 is 10.0
# Total Reward for episode 94 is 10.0
# Total Reward for episode 95 is 10.0
# Total Reward for episode 96 is 6.0
# Total Reward for episode 97 is 7.0
# Total Reward for episode 98 is 10.0
# Total Reward for episode 99 is 11.0
# Total Reward for episode 100 is 8.0

# %%
env.close()
